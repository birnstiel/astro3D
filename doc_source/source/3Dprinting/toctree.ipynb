# %% [markdown]
# # 3D Printing

# %% [markdown]
# [Introduction to printing 3D densities](1_introduction3D.ipynb)

# %% [markdown]
# ### Turbulent Box

# %% [markdown]
# - [Slicing a turbulent box for 3D printing](1_turbulent_box/1_link.ipynb)
# - [Analyze image stack of turbulent box](1_turbulent_box/2_link.ipynb)

# %% [markdown]
# ### MHD Disk & Field Lines

# %% [markdown]
# - [Compute MHD fieldlines for 3D printing](3_mhd/1_link.ipynb)
# - [Slicing a MHD simulation with field lines](3_mhd/2_link.ipynb)
# - [Analyze MHD image stack](3_mhd/3_link.ipynb)

# %% [markdown]
# ### Colored Dust Disk

# %% [markdown]
# - [3D color printing a dust disk](4_color_disk/1_link.ipynb)
# - [Analyze the disk image stack](4_color_disk/2_link.ipynb)

# %% [markdown]
# ### Local Box

# %% [markdown]
# - [Local Box](5_localbox/1_link.ipynb)
